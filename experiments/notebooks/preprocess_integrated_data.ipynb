# %%
import pandas as pd 
import re

# %%
df = pd.read_csv("../../datasets/processed/integrated_dataset.v2.csv")

# %%
df.head()
# Out:
#        job_id                                     title  \
# 0  MER000441Q                 Manager, Public Relations
# 1  MER0003T59         Assistant Manager, Tax Specialist
# 2  MER00044DU  Process Engineer – Automation & Controls
# 3  MER00044DN          Full Stack Developer - HUD Miner
# 4  MER0003ZHY                         C# .NET Developer
#
#                            field_of_work posted_since  \
# 0                                 Others   2026-06-15
# 1                    Finance/Controlling   2026-06-15
# 2                             Production   2026-06-15
# 3  Research and Development incl. Design   2026-06-15
# 4  Research and Development incl. Design   2026-06-15
#
#                                              company  \
# 0                   Mercedes-Benz Malaysia Sdn. Bhd.
# 1                   Mercedes-Benz Malaysia Sdn. Bhd.
# 2     Mercedes-Benz Manufacturing Poland sp. z o. o.
# 3  Mercedes-Benz Research and Development India P...
# ...

# %%
print(df.clean_description.to_list()[10])
# Out:
# mercedes-benz ag is responsible for the global business of mercedes-benz cars and mercedes-benz vans worldwide. the company's focus is on the development, production and sales of cars and vans as well as services. are you a pupil or student or are you in the transition period between school and studies/training, are you motivated and would you like to support us? then you have come to the right place with us as part of a holiday job and we look forward to receiving your application. to work at the mercedes-benz plant in bremen, we are looking for holiday employees (f/m/d) in the area of ​​production and logistics with, among other things, the following tasks: assembly work, she will construction work, working in the press shop, driving a forklift. depending on the tariff area within the location, you will have a weekly working time of 35/38/39 hours you are attending school or studying or are in the transition period between school and studies/training/secondary school or federal vol
# ...

# %%
df.clean_description.to_list()[41]
# Out:
# "in our logistics engineering technologies & advanced logistics team, we work at arena2036 on the campus of the university of stuttgart on pioneering robotics solutions for intralogistics. as part of an ongoing research project, we are developing a flexible bin-picking system together with partners from industry and research.as an intern on our team, you will support the operation and furtheresearch and developmentevelopment of one of our mobile robotic demonstrators. your tasks will include:operation, maintenance, and support of the demonstratoresearch and developmenturing test campaigns and demonstrationsextension and maintenance of the state machine orchestrating the robot's behaviormaintenance and improvement of the motion planning stackintegration of additional hardware and software components into the overall systemcontributing to the ros2, mqtt, and rest interfaces between the system's componentswe offer you the opportunity to gain hands-on experience with state-of-the-art rob
# ...

# %%
#!pip install wordninja

# %%
import wordninja

text = "researchanddevelopmentevelopment"

print(" ".join(wordninja.split(df.clean_description.to_list()[41])))
# Out:
# in our logistics engineering technologies advanced logistics team we work at arena 2036 on the campus of the university of stuttgart on pioneering robotics solutions for intra logistics as part of an ongoing research project we are developing a flexible bin picking system together with partners from industry and research as an intern on our team you will support the operation and fur the research and development eve lop ment of one of our mobile robotic demonstrators your tasks will include operation maintenance and support of the demonstrator e search and development u ring test campaigns and demonstrations extension and maintenance of the state machine orchestrating the robot's behavior maintenance and improvement of the motion planning stack integration of additional hardware and software components into the overall system contributing to the ros 2 m qt t and rest interfaces between the system's components we offer you the opportunity to gain hands on experience with state of the 
# ...

# %%
we look forward to receiving your application!
please check your email inbox and spam folder regularly for further information about your application
 we particularly welcome online applications from do you have questions? 
 you can find answers and further contact options in our faq 
you can also use our chat function to receive further information.
§
